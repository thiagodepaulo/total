# %%
# %matplotlib inline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV    
from preprocessor import Preprocessor
from util import Loader
import pandas as pd
import logging
import sys
from sklearn.metrics import classification_report
from imbhn import IMBHN


# carrega a base
s_dataset = '/exp/datasets/docs_rotulados/CSTR'        
l = Loader()
d = l.from_files(s_dataset)

# %%
# Préprocessamento

#cvect = CountVectorizer(min_df=2)
cvect = CountVectorizer()
#steps = [ ('preprocessor',Preprocessor()), ('countvectorizer',cvect), ('multinomialnaivebayes',MultinomialNB())]
steps = [ ('preprocessor',Preprocessor()), ('countvectorizer',cvect), ('imbhn', IMBHN())]
text_clf = Pipeline(steps)

# %%
parameters = {}
gs_clf = GridSearchCV(text_clf, parameters, cv=10, scoring='accuracy', n_jobs=-1, return_train_score=False)
gs_clf = gs_clf.fit(d['corpus'], d['class_index'])
df = pd.DataFrame(gs_clf.cv_results_)
df
# Out:
# running
# oi1000
# running
# oi1000
# running
# oi1000
# running
# oi1000
# 1000
# 1
# 0.04477611940298507
# 1000
# 1
# 0.04664179104477612
# 1000
# 1
# 0.04664179104477612
# 1000
# 1
# 0.04664179104477612
# 1000
# 2
# 0.08582089552238806
# 1000
# 2
# 0.06343283582089553
# 1000
# 2
# 0.06716417910447761
# 1000
# 2
# 0.06716417910447761
# 1000
# 3
# 0.08955223880597014
# 1000
# 3
# 0.07835820895522388
# 1000
# 3
# 0.08955223880597014
# 1000
# 3
# 0.09701492537313433
# 1000
# 4
# 0.06716417910447761
# 1000
# 4
# 0.07835820895522388
# 1000
# 4
# 0.10074626865671642
# 1000
# 4
# 0.0708955223880597
# 1000
# 5
# 0.07462686567164178
# 1000
# 5
# 0.055970149253731345
# 1000
# 5
# 0.08208955223880597
# 1000
# 5
# 0.05223880597014925
# 1000
# 6
# 0.05223880597014925
# 1000
# 6
# 0.06716417910447761
# 1000
# 6
# 0.041044776119402986
# 1000
# 6
# 0.055970149253731345
# 1000
# 7
# 0.05970149253731343
# 1000
# 7
# 0.048507462686567165
# 1000
# 7
# 0.04477611940298507
# 1000
# 7
# ...
